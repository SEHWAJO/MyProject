# %%
# %matplotlib inline

import numpy as np
import pandas as pd


# 프로파일링
from pandas.plotting import scatter_matrix
from pandas_profiling import ProfileReport

# 사이킷런 - 데이터 셋 나누기
from sklearn.model_selection import train_test_split

# 사이킷런 - encoders & imputers
from category_encoders import OneHotEncoder
from category_encoders import OrdinalEncoder
from sklearn.impute import SimpleImputer


from sklearn.preprocessing import StandardScaler

# 사이킷런 - 파이프라인
from sklearn.pipeline import make_pipeline

# 사이킷런 - 학습모델
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso

# 사이킷런 - 모델 평가 지표
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

#분류문제 평가지표
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve


# 회귀방정식 평가지표
from sklearn.metrics import  mean_squared_error, mean_absolute_error, r2_score




# f_regresison, SelectKBest
from sklearn.feature_selection import f_regression, SelectKBest

# GridSearchCV
from sklearn.model_selection import GridSearchCV


# RidgeCV
from sklearn.linear_model import RidgeCV

# 다항회귀
from sklearn.preprocessing import PolynomialFeatures

import graphviz
from sklearn.tree import export_graphviz



from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge

from sklearn.impute import KNNImputer, SimpleImputer




# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CSV파일 불러오기
df = pd.read_csv('/Users/sehwajo/Downloads/BankChurners.csv')

# %%
# 판다스 프로파일링 실행하여 간단히 EDA
#df.profile_report()

# %%
# 컬럼 종류 확인

for columns in df.columns:
    print(columns)
# Out:
# CLIENTNUM
# Attrition_Flag
# Customer_Age
# Gender
# Dependent_count
# Education_Level
# Marital_Status
# Income_Category
# Card_Category
# Months_on_book
# Total_Relationship_Count
# Months_Inactive_12_mon
# Contacts_Count_12_mon
# Credit_Limit
# Total_Revolving_Bal
# Avg_Open_To_Buy
# Total_Amt_Chng_Q4_Q1
# Total_Trans_Amt
# Total_Trans_Ct
# Total_Ct_Chng_Q4_Q1
# Avg_Utilization_Ratio
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2

# %%
# 필요없는 컬럼 제거

df = df.drop(['CLIENTNUM','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis = 1)

# %%
# 컬럼이 잘 제거되었는지 사이즈로 확인
df.shape
# Out:
# (10127, 20)

# %%
df
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                  39                         5                       1
# 1                  44                         6                       1
# 2                  36                         4                       1
# 3                  34                         3                       4
# 4                  21                         5                       1
# ...               ...                       ...                     ...
# 10122              40                         3                       2
# 10123              25                         4                       2
# 10124              36                         5                       3
# 10125              36                         4                       3
# 10126              25                         6                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                          3       12691.0                  777
# 1                          2        8256.0                  864
# 2                          0        3418.0                    0
# 3                          1        3313.0                 2517
# 4                          0        4716.0                    0
# ...                      ...           ...                  ...
# 10122                      3        4003.0                 1851
# 10123                      3        4277.0                 2186
# 10124                      4        5409.0                    0
# 10125                      3        5281.0                    0
# 10126                      4       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [10127 rows x 20 columns]

# %%
# 데이터의 전반적인 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            10127 non-null  object
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  object
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           10127 non-null  object
#  5   Marital_Status            10127 non-null  object
#  6   Income_Category           10127 non-null  object
#  7   Card_Category             10127 non-null  object
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
#  13  Total_Revolving_Bal       10127 non-null  int64
#  14  Avg_Open_To_Buy           10127 non-null  float64
#  15  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  16  Total_Trans_Amt           10127 non-null  int64
#  17  Total_Trans_Ct            10127 non-null  int64
#  18  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  19  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(9), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 각 컬럼 시각화로 살펴보기

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = df['Attrition_Flag'])
plt.show()

plt.figure(figsize = (10,5))
sns.countplot(x = df['Card_Category'])
plt.show()

plt.figure(figsize = (10,5))
sns.countplot(x= df['Education_Level'])
plt.show()

plt.figure(figsize = (10,5))
sns.countplot(x = df['Marital_Status'])
plt.show()

plt.figure(figsize = (10,5))
sns.countplot(x = df['Income_Category'])
plt.show()

# %% [markdown]
# # 데이터셋 나누기

# %%
# 훈련용과 테스트 용으로 데이터세트 나누기
train, test = train_test_split(df,test_size=0.2, random_state=2)


# 훈련용 데이터를 다시 나누기 : 훈련용(80%), 검증용(20%)
train, val = train_test_split(train, test_size=0.2, random_state=2)



# 타겟은 Attrition_Flag
# 'Attrition_Flag' 컬럼에서 Existing Customer는 이탈하지 않은 고객, Attrited Customer는 이탈한 고객
# 훈련, 검증, 테스트 데이터 세트를 타겟과 나머지 데이터로 나누기

X_train = train.drop(['Attrition_Flag'], axis= 1)
y_train = train.Attrition_Flag

X_val = val.drop(['Attrition_Flag'], axis= 1)
y_val = val.Attrition_Flag


X_test = test.drop(['Attrition_Flag'], axis= 1)
y_test = test.Attrition_Flag

# 확인
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_val.shape, y_val.shape
# Out:
# ((6480, 19), (6480,), (1621, 19), (1621,), (1621, 19), (1621,))

# %% [markdown]
# # 타켓 정보 확인

# %%
# 타겟 데이터 범주의 비율을 확인합니다.
df['Attrition_Flag'].value_counts(normalize=True)
# Out:
# Existing Customer    0.83934
# Attrited Customer    0.16066
# Name: Attrition_Flag, dtype: float64

# %%
# %matplotlib inline

target = df['Attrition_Flag']
sns.countplot(x=target);

# %% [markdown]
# 타겟값인 Attrition_Flag데이터가 불균형한 것을 볼 수 있다.
# 이런 비대칭 데이터셋에서는 정확도가 높아도 재현율이 급격하게 작아지는 현상이 발생하게 된다.
# 100개의 데이터 중 3개가 부실이면 모두 정상이라고 예측해도 정확도가 97%가 나오기 때문이다.
# 이런 데이터 불균형을 처리하는 방법에는 여러가지가 있는데 그 중 '업샘플링'을 사용할 것이다.
# 업샘플링은 기준을 정해서 무작위로 소수 데이터를 복제한다. 정보가 손실되지 않는다는 장점이 있으나, 오버피팅을 초래하여 trainset의 성능은 높지만 testset의 성능은 나빠질 수 있다.

# %% [markdown]
# # 기준모델 만들기

# %%
# mode(): Return the highest frequency value in a Series.
major = y_train.mode()[0]

# 타겟 샘플 수 만큼 0이 담긴 리스트를 만듭니다. 기준모델로 예측
y_pred = [major] * len(y_train)

# 최다 클래스의 빈도가 정확도가 됩니다.
# 훈련세트에서 정확도 확인
print("training accuracy: ", accuracy_score(y_train, y_pred))

# 검증세트 에서도 정확도를 확인
y_pred = [major] * len(y_val)
print("validation accuracy: ", accuracy_score(y_val, y_pred))
# Out:
# training accuracy:  0.8379629629629629
# validation accuracy:  0.8365206662553979

# %%
# df3 = df['Card_Category'].value_counts()
# plt.figure(figsize = (10,5))
# df3.plot.pie(autopct='%.2f%%')
# plt.axis('equal')
# plt.show()

# %% [markdown]
# ## 결측치, 중복값, 카디널리티 확인

# %%
# 결측치 확인 - 결측치는 없지만 unknown 값이 있어서 처리할 필요가 있음
df.isnull().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# 중복값 확인
df.T.duplicated()
# Out:
# Attrition_Flag              False
# Customer_Age                False
# Gender                      False
# Dependent_count             False
# Education_Level             False
# Marital_Status              False
# Income_Category             False
# Card_Category               False
# Months_on_book              False
# Total_Relationship_Count    False
# Months_Inactive_12_mon      False
# Contacts_Count_12_mon       False
# Credit_Limit                False
# Total_Revolving_Bal         False
# Avg_Open_To_Buy             False
# Total_Amt_Chng_Q4_Q1        False
# Total_Trans_Amt             False
# Total_Trans_Ct              False
# Total_Ct_Chng_Q4_Q1         False
# Avg_Utilization_Ratio       False
# dtype: bool

# %%
# 너무 많은 범주를 가지는 카테고리 특성이 있는지  카디널리티(cardinality)를 확인
df.describe(exclude='number').T.sort_values(by='unique')
# Out:
#                  count unique                top  freq
# Attrition_Flag   10127      2  Existing Customer  8500
# Gender           10127      2                  F  5358
# Marital_Status   10127      4            Married  4687
# Card_Category    10127      4               Blue  9436
# Income_Category  10127      6     Less than $40K  3561
# Education_Level  10127      7           Graduate  3128

# %% [markdown]
# # Feature Engineering

# %%
# Education_Level이 Unknown인 값 제거하기
df = df[df.Education_Level != 'Unknown']

# Marital_Status가 Unknown인 값 제거하기
df = df[df.Marital_Status != 'Unknown']

# Income_Category가 Unknown인 값 제거하기
df = df[df.Income_Category != 'Unknown']

# Unknown 값이 전부 잘 제거되었는지 확인
print(df['Education_Level'].unique())
print(df['Marital_Status'].unique())
print(df['Income_Category'].unique())
# Out:
# ['High School' 'Graduate' 'Uneducated' 'College' 'Post-Graduate'
#  'Doctorate']
# ['Married' 'Single' 'Divorced']
# ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +']

# %% [markdown]
# # 카테고리 데이터 처리를 위해 원핫인코딩을 수행
# 원핫인코딩을 수행하여 카테고리형 데이터를 수치형 데이터로 변경해줍니다.
# 주의할 점 : 카테고리가 너무 많은 경우(high cardinality)에는 사용하기 적합하지 않다.

# %%
encoder = OneHotEncoder(use_cat_names=True)
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)
X_test_encoded = encoder.transform(X_test)
X_train_encoded.head(3)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#       Customer_Age  Gender_M  Gender_F  Dependent_count  \
# 9047            50         1         0                1
# 137             45         1         0                4
# 3538            46         1         0                3
#
#       Education_Level_Post-Graduate  Education_Level_College  \
# 9047                              1                        0
# 137                               0                        1
# 3538                              0                        0
#
#       Education_Level_Graduate  Education_Level_Uneducated  \
# 9047                         0                           0
# 137                          0                           0
# 3538                         1                           0
#
#       Education_Level_Unknown  Education_Level_High School  ...  \
# 9047                        0                            0  ...
# 137                         0                            0  ...
# 3538                        0                            0  ...
#
#       Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 9047                       3                      2       34516.0
# 137                        1                      0       10408.0
# 3538                       1                      2        8101.0
#
#       Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 9047                    0          34516.0                 1.032
# 137                  1186           9222.0                 1.689
# 3538                 1266           6835.0                 0.615
#
#       Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 9047             5547              75                0.744
# 137              2560              42                1.211
# 3538             3226              53                0.710
#
#       Avg_Utilization_Ratio
# 9047                  0.000
# 137                   0.114
# 3538                  0.156
#
# [3 rows x 37 columns]

# %% [markdown]
# # StandardScaler
# 특성들의 척도를 맞추기 위해 표준정규분포로 표준화하는(평균=0, 표준편차=1) StandardScaler

# %%
# 특성값들을 표준화 합니다


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_val_scaled = scaler.transform(X_val_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

# %%
X_train_scaled
# Out:
# array([[ 0.45794453,  1.05587997, -1.05587997, ...,  0.44019815,
#          0.12279548, -0.99419249],
#        [-0.15914925,  1.05587997, -1.05587997, ..., -0.96633115,
#          2.0402693 , -0.58016164],
#        [-0.03573049,  1.05587997, -1.05587997, ..., -0.49748805,
#         -0.01680647, -0.42762395],
#        ...,
#        [-0.89966178,  1.05587997, -1.05587997, ..., -0.24175545,
#         -0.30832819, -0.80170446],
#        [-0.282568  ,  1.05587997, -1.05587997, ...,  0.90904125,
#          0.02425292, -0.82712741],
#        [ 0.70478204, -0.94707735,  0.94707735, ...,  1.03690755,
#          0.73868642,  1.13043954]])

# %%
# 평균은 0, 표준편차는 1로 표준화 되었습니다.
X_train_scaled.T[0].mean(), X_train_scaled.T[0].std()
# Out:
# (-3.5856091758264317e-16, 1.0)

# %%
#상관관계분석

# 원래 데이터 상관관계분석을 확인하기 위해 원핫인코딩 작업
encoder = OneHotEncoder(use_cat_names=True)
df_encoded = encoder.fit_transform(df)


sns.heatmap(df_encoded.corr())
plt.rcParams['figure.figsize'] = [20,20]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df_encoded.corr(method='pearson')
# Out:
#                                   Attrition_Flag_Existing Customer  \
# Attrition_Flag_Existing Customer                          1.000000
# Attrition_Flag_Attrited Customer                         -1.000000
# Customer_Age                                             -0.008735
# Gender_M                                                  0.035358
# Gender_F                                                 -0.035358
# Dependent_count                                          -0.011423
# Education_Level_High School                               0.020932
# Education_Level_Graduate                                  0.001012
# Education_Level_Uneducated                                0.003353
# Education_Level_College                                   0.000791
# Education_Level_Post-Graduate                            -0.015019
# Education_Level_Doctorate                                -0.033169
# Marital_Status_Married                                    0.024207
# Marital_Status_Single                                    -0.022535
# Marital_Status_Divorced                                  -0.003659
# Income_Category_$60K - $80K                               0.030356
# Income_Category_Less than $40K                           -0.027114
# Income_Category_$80K - $120K                             -0.000070
# Income_Category_$40K - $60K                               0.017421
# Income_Category_$120K +                                  -0.017218
# Card_Category_Blue                                        0.004743
# Card_Category_Gold                                       -0.000979
# Card_Category_Silver                                     -0.002620
# Card_Category_Platinum                                   -0.012522
# Months_on_book                                           -0.009249
# Total_Relationship_Count                                  0.145713
# Months_Inactive_12_mon                                   -0.152732
# Contacts_Count_12_mon                                    -0.193923
# Credit_Limit                                              0.015815
# Total_Revolving_Bal                                       0.265380
# Avg_Open_To_Buy                                          -0.007802
# Total_Amt_Chng_Q4_Q1                                      0.132702
# Total_Trans_Amt                                           0.160378
# Total_Trans_Ct                                            0.357261
# Total_Ct_Chng_Q4_Q1                                       0.280460
# Avg_Utilization_Ratio                                     0.183984
#
#                                   Attrition_Flag_Attrited Customer  \
# Attrition_Flag_Existing Customer                         -1.000000
# Attrition_Flag_Attrited Customer                          1.000000
# Customer_Age                                              0.008735
# Gender_M                                                 -0.035358
# Gender_F                                                  0.035358
# Dependent_count                                           0.011423
# Education_Level_High School                              -0.020932
# Education_Level_Graduate                                 -0.001012
# Education_Level_Uneducated                               -0.003353
# Education_Level_College                                  -0.000791
# Education_Level_Post-Graduate                             0.015019
# Education_Level_Doctorate                                 0.033169
# Marital_Status_Married                                   -0.024207
# Marital_Status_Single                                     0.022535
# Marital_Status_Divorced                                   0.003659
# Income_Category_$60K - $80K                              -0.030356
# Income_Category_Less than $40K                            0.027114
# Income_Category_$80K - $120K                              0.000070
# Income_Category_$40K - $60K                              -0.017421
# Income_Category_$120K +                                   0.017218
# Card_Category_Blue                                       -0.004743
# Card_Category_Gold                                        0.000979
# Card_Category_Silver                                      0.002620
# Card_Category_Platinum                                    0.012522
# Months_on_book                                            0.009249
# Total_Relationship_Count                                 -0.145713
# Months_Inactive_12_mon                                    0.152732
# Contacts_Count_12_mon                                     0.193923
# Credit_Limit                                             -0.015815
# Total_Revolving_Bal                                      -0.265380
# Avg_Open_To_Buy                                           0.007802
# Total_Amt_Chng_Q4_Q1                                     -0.132702
# Total_Trans_Amt                                          -0.160378
# Total_Trans_Ct                                           -0.357261
# Total_Ct_Chng_Q4_Q1                                      -0.280460
# Avg_Utilization_Ratio                                    -0.183984
#
#                                   Customer_Age  Gender_M  Gender_F  \
# Attrition_Flag_Existing Customer     -0.008735  0.035358 -0.035358
# Attrition_Flag_Attrited Customer      0.008735 -0.035358  0.035358
# Customer_Age                          1.000000 -0.010569  0.010569
# Gender_M                             -0.010569  1.000000 -1.000000
# Gender_F                              0.010569 -1.000000  1.000000
# Dependent_count                      -0.128232  0.008121 -0.008121
# Education_Level_High School           0.008855  0.019963 -0.019963
# Education_Level_Graduate             -0.003787 -0.011187  0.011187
# Education_Level_Uneducated            0.004179  0.000647 -0.000647
# Education_Level_College              -0.011245 -0.000634  0.000634
# Education_Level_Post-Graduate        -0.023570 -0.000678  0.000678
# Education_Level_Doctorate             0.026417 -0.013380  0.013380
# Marital_Status_Married                0.043201  0.017927 -0.017927
# Marital_Status_Single                -0.018456 -0.015431  0.015431
# Marital_Status_Divorced              -0.045991 -0.004992  0.004992
# Income_Category_$60K - $80K          -0.022497  0.409915 -0.409915
# Income_Category_Less than $40K       -0.007431 -0.718754  0.718754
# Income_Category_$80K - $120K          0.012308  0.431504 -0.431504
# Income_Category_$40K - $60K          -0.018767 -0.091291  0.091291
# Income_Category_$120K +               0.053827  0.282895 -0.282895
# Card_Category_Blue                    0.005081 -0.091084  0.091084
# Card_Category_Gold                   -0.005643  0.041498 -0.041498
# Card_Category_Silver                 -0.003072  0.078438 -0.078438
# Card_Category_Platinum                0.000524  0.016103 -0.016103
# Months_on_book                        0.791271 -0.003813  0.003813
# Total_Relationship_Count             -0.022067 -0.004505  0.004505
# Months_Inactive_12_mon                0.057870 -0.011282  0.011282
# Contacts_Count_12_mon                -0.023971  0.045244 -0.045244
# Credit_Limit                          0.024563  0.476471 -0.476471
# Total_Revolving_Bal                   0.016325  0.020816 -0.020816
# Avg_Open_To_Buy                       0.023097  0.474351 -0.474351
# Total_Amt_Chng_Q4_Q1                 -0.068976  0.034839 -0.034839
# Total_Trans_Amt                      -0.045859  0.034648 -0.034648
# Total_Trans_Ct                       -0.069883 -0.055468  0.055468
# Total_Ct_Chng_Q4_Q1                  -0.017599 -0.007336  0.007336
# Avg_Utilization_Ratio                 0.001296 -0.309002  0.309002
#
#                                   Dependent_count  \
# Attrition_Flag_Existing Customer        -0.011423
# Attrition_Flag_Attrited Customer         0.011423
# Customer_Age                            -0.128232
# Gender_M                                 0.008121
# Gender_F                                -0.008121
# Dependent_count                          1.000000
# Education_Level_High School             -0.017678
# Education_Level_Graduate                 0.008795
# Education_Level_Uneducated              -0.002829
# Education_Level_College                  0.013462
# Education_Level_Post-Graduate            0.007046
# Education_Level_Doctorate               -0.007952
# Marital_Status_Married                   0.025163
# Marital_Status_Single                   -0.032574
# Marital_Status_Divorced                  0.012786
# Income_Category_$60K - $80K              0.022132
# Income_Category_Less than $40K          -0.058431
# Income_Category_$80K - $120K             0.047172
# Income_Category_$40K - $60K             -0.015046
# Income_Category_$120K +                  0.032412
# Card_Category_Blue                      -0.038098
# Card_Category_Gold                       0.031503
# Card_Category_Silver                     0.026769
# Card_Category_Platinum                   0.003565
# Months_on_book                          -0.112368
# Total_Relationship_Count                -0.043257
# Months_Inactive_12_mon                  -0.022804
# Contacts_Count_12_mon                   -0.055625
# Credit_Limit                             0.081379
# Total_Revolving_Bal                     -0.003832
# Avg_Open_To_Buy                          0.081674
# Total_Amt_Chng_Q4_Q1                    -0.033320
# Total_Trans_Amt                          0.023236
# Total_Trans_Ct                           0.057056
# Total_Ct_Chng_Q4_Q1                      0.019081
# Avg_Utilization_Ratio                   -0.042485
#
#                                   Education_Level_High School  \
# Attrition_Flag_Existing Customer                     0.020932
# Attrition_Flag_Attrited Customer                    -0.020932
# Customer_Age                                         0.008855
# Gender_M                                             0.019963
# Gender_F                                            -0.019963
# Dependent_count                                     -0.017678
# Education_Level_High School                          1.000000
# Education_Level_Graduate                            -0.419206
# Education_Level_Uneducated                          -0.249777
# Education_Level_College                             -0.203002
# Education_Level_Post-Graduate                       -0.140490
# Education_Level_Doctorate                           -0.127343
# Marital_Status_Married                               0.009357
# Marital_Status_Single                                0.001906
# Marital_Status_Divorced                             -0.020666
# Income_Category_$60K - $80K                          0.025329
# Income_Category_Less than $40K                      -0.020336
# Income_Category_$80K - $120K                        -0.004088
# Income_Category_$40K - $60K                          0.001153
# Income_Category_$120K +                              0.006703
# Card_Category_Blue                                   0.014238
# Card_Category_Gold                                   0.006565
# Card_Category_Silver                                -0.016481
# Card_Category_Platinum                              -0.013290
# Months_on_book                                       0.009671
# Total_Relationship_Count                             0.005960
# Months_Inactive_12_mon                              -0.006485
# Contacts_Count_12_mon                               -0.000065
# Credit_Limit                                        -0.008820
# Total_Revolving_Bal                                  0.028286
# Avg_Open_To_Buy                                     -0.011331
# Total_Amt_Chng_Q4_Q1                                 0.000154
# Total_Trans_Amt                                      0.003117
# Total_Trans_Ct                                       0.000898
# Total_Ct_Chng_Q4_Q1                                  0.000407
# Avg_Utilization_Ratio                                0.013911
#
#                                   Education_Level_Graduate  \
# Attrition_Flag_Existing Customer                  0.001012
# Attrition_Flag_Attrited Customer                 -0.001012
# Customer_Age                                     -0.003787
# Gender_M                                         -0.011187
# Gender_F                                          0.011187
# Dependent_count                                   0.008795
# Education_Level_High School                      -0.419206
# Education_Level_Graduate                          1.000000
# Education_Level_Uneducated                       -0.343832
# Education_Level_College                          -0.279443
# Education_Level_Post-Graduate                    -0.193392
# Education_Level_Doctorate                        -0.175295
# Marital_Status_Married                            0.012842
# Marital_Status_Single                            -0.005769
# Marital_Status_Divorced                          -0.013160
# Income_Category_$60K - $80K                      -0.013419
# Income_Category_Less than $40K                    0.018228
# Income_Category_$80K - $120K                      0.004044
# Income_Category_$40K - $60K                      -0.005623
# Income_Category_$120K +                          -0.012158
# Card_Category_Blue                               -0.013102
# Card_Category_Gold                                0.000996
# Card_Category_Silver                              0.014030
# Card_Category_Platinum                           -0.000186
# Months_on_book                                    0.000707
# Total_Relationship_Count                          0.002278
# Months_Inactive_12_mon                            0.010697
# Contacts_Count_12_mon                             0.001726
# Credit_Limit                                     -0.001607
# Total_Revolving_Bal                              -0.011963
# Avg_Open_To_Buy                                  -0.000541
# Total_Amt_Chng_Q4_Q1                             -0.012657
# Total_Trans_Amt                                  -0.000157
# Total_Trans_Ct                                   -0.004422
# Total_Ct_Chng_Q4_Q1                               0.000382
# Avg_Utilization_Ratio                            -0.002013
#
#                                   Education_Level_Uneducated  \
# Attrition_Flag_Existing Customer                    0.003353
# Attrition_Flag_Attrited Customer                   -0.003353
# Customer_Age                                        0.004179
# Gender_M                                            0.000647
# Gender_F                                           -0.000647
# Dependent_count                                    -0.002829
# Education_Level_High School                        -0.249777
# Education_Level_Graduate                           -0.343832
# Education_Level_Uneducated                          1.000000
# Education_Level_College                            -0.166502
# Education_Level_Post-Graduate                      -0.115229
# Education_Level_Doctorate                          -0.104447
# Marital_Status_Married                             -0.021049
# Marital_Status_Single                               0.008194
# Marital_Status_Divorced                             0.023857
# Income_Category_$60K - $80K                        -0.005749
# Income_Category_Less than $40K                      0.011746
# Income_Category_$80K - $120K                       -0.006388
# Income_Category_$40K - $60K                        -0.013253
# Income_Category_$120K +                             0.014819
# Card_Category_Blue                                  0.007643
# Card_Category_Gold                                 -0.009802
# Card_Category_Silver                               -0.004086
# Card_Category_Platinum                              0.001238
# Months_on_book                                     -0.005429
# Total_Relationship_Count                            0.002062
# Months_Inactive_12_mon                             -0.002833
# Contacts_Count_12_mon                               0.026824
# Credit_Limit                                        0.014856
# Total_Revolving_Bal                                -0.000682
# Avg_Open_To_Buy                                     0.014908
# Total_Amt_Chng_Q4_Q1                                0.008064
# Total_Trans_Amt                                     0.009537
# Total_Trans_Ct                                      0.007516
# Total_Ct_Chng_Q4_Q1                                 0.015138
# Avg_Utilization_Ratio                              -0.004793
#
#                                   Education_Level_College  ...  \
# Attrition_Flag_Existing Customer                 0.000791  ...
# Attrition_Flag_Attrited Customer                -0.000791  ...
# Customer_Age                                    -0.011245  ...
# Gender_M                                        -0.000634  ...
# Gender_F                                         0.000634  ...
# Dependent_count                                  0.013462  ...
# Education_Level_High School                     -0.203002  ...
# Education_Level_Graduate                        -0.279443  ...
# Education_Level_Uneducated                      -0.166502  ...
# Education_Level_College                          1.000000  ...
# Education_Level_Post-Graduate                   -0.093651  ...
# Education_Level_Doctorate                       -0.084887  ...
# Marital_Status_Married                          -0.002442  ...
# Marital_Status_Single                           -0.004756  ...
# Marital_Status_Divorced                          0.013115  ...
# Income_Category_$60K - $80K                     -0.011381  ...
# Income_Category_Less than $40K                  -0.010510  ...
# Income_Category_$80K - $120K                     0.021747  ...
# Income_Category_$40K - $60K                      0.006219  ...
# Income_Category_$120K +                         -0.005083  ...
# Card_Category_Blue                              -0.009388  ...
# Card_Category_Gold                               0.017811  ...
# Card_Category_Silver                             0.004572  ...
# Card_Category_Platinum                          -0.014510  ...
# Months_on_book                                  -0.006660  ...
# Total_Relationship_Count                        -0.014550  ...
# Months_Inactive_12_mon                           0.000806  ...
# Contacts_Count_12_mon                           -0.019551  ...
# Credit_Limit                                     0.005530  ...
# Total_Revolving_Bal                             -0.011015  ...
# Avg_Open_To_Buy                                  0.006507  ...
# Total_Amt_Chng_Q4_Q1                             0.012083  ...
# Total_Trans_Amt                                 -0.013940  ...
# Total_Trans_Ct                                  -0.000600  ...
# Total_Ct_Chng_Q4_Q1                              0.008889  ...
# Avg_Utilization_Ratio                           -0.009862  ...
#
#                                   Months_Inactive_12_mon  \
# Attrition_Flag_Existing Customer               -0.152732
# Attrition_Flag_Attrited Customer                0.152732
# Customer_Age                                    0.057870
# Gender_M                                       -0.011282
# Gender_F                                        0.011282
# Dependent_count                                -0.022804
# Education_Level_High School                    -0.006485
# Education_Level_Graduate                        0.010697
# Education_Level_Uneducated                     -0.002833
# Education_Level_College                         0.000806
# Education_Level_Post-Graduate                  -0.000988
# Education_Level_Doctorate                      -0.006253
# Marital_Status_Married                         -0.009098
# Marital_Status_Single                           0.011515
# Marital_Status_Divorced                        -0.004147
# Income_Category_$60K - $80K                    -0.001133
# Income_Category_Less than $40K                  0.032074
# Income_Category_$80K - $120K                   -0.004466
# Income_Category_$40K - $60K                    -0.028332
# Income_Category_$120K +                        -0.008318
# Card_Category_Blue                              0.005899
# Card_Category_Gold                             -0.002337
# Card_Category_Silver                           -0.006810
# Card_Category_Platinum                          0.008041
# Months_on_book                                  0.071305
# Total_Relationship_Count                        0.005072
# Months_Inactive_12_mon                          1.000000
# Contacts_Count_12_mon                           0.026269
# Credit_Limit                                   -0.015728
# Total_Revolving_Bal                            -0.039889
# Avg_Open_To_Buy                                -0.012170
# Total_Amt_Chng_Q4_Q1                           -0.028157
# Total_Trans_Amt                                -0.039977
# Total_Trans_Ct                                 -0.048169
# Total_Ct_Chng_Q4_Q1                            -0.039581
# Avg_Utilization_Ratio                          -0.003179
#
#                                   Contacts_Count_12_mon  Credit_Limit  \
# Attrition_Flag_Existing Customer              -0.193923      0.015815
# Attrition_Flag_Attrited Customer               0.193923     -0.015815
# Customer_Age                                  -0.023971      0.024563
# Gender_M                                       0.045244      0.476471
# Gender_F                                      -0.045244     -0.476471
# Dependent_count                               -0.055625      0.081379
# Education_Level_High School                   -0.000065     -0.008820
# Education_Level_Graduate                       0.001726     -0.001607
# Education_Level_Uneducated                     0.026824      0.014856
# Education_Level_College                       -0.019551      0.005530
# Education_Level_Post-Graduate                 -0.012227     -0.001980
# Education_Level_Doctorate                     -0.007407     -0.010929
# Marital_Status_Married                         0.006217     -0.053616
# Marital_Status_Single                         -0.002524      0.044681
# Marital_Status_Divorced                       -0.006858      0.017592
# Income_Category_$60K - $80K                    0.002022      0.103199
# Income_Category_Less than $40K                -0.015913     -0.419655
# Income_Category_$80K - $120K                   0.011830      0.369814
# Income_Category_$40K - $60K                   -0.003740     -0.172761
# Income_Category_$120K +                        0.015035      0.359109
# Card_Category_Blue                            -0.001267     -0.496172
# Card_Category_Gold                            -0.003379      0.229254
# Card_Category_Silver                           0.002970      0.426009
# Card_Category_Platinum                         0.000003      0.086502
# Months_on_book                                -0.011054      0.020103
# Total_Relationship_Count                       0.070539     -0.074876
# Months_Inactive_12_mon                         0.026269     -0.015728
# Contacts_Count_12_mon                          1.000000      0.016737
# Credit_Limit                                   0.016737      1.000000
# Total_Revolving_Bal                           -0.048690      0.038170
# Avg_Open_To_Buy                                0.021059      0.996041
# Total_Amt_Chng_Q4_Q1                          -0.027849      0.001973
# Total_Trans_Amt                               -0.121018      0.171591
# Total_Trans_Ct                                -0.155612      0.080834
# Total_Ct_Chng_Q4_Q1                           -0.099544     -0.005991
# Avg_Utilization_Ratio                         -0.043495     -0.483649
#
#                                   Total_Revolving_Bal  Avg_Open_To_Buy  \
# Attrition_Flag_Existing Customer             0.265380        -0.007802
# Attrition_Flag_Attrited Customer            -0.265380         0.007802
# Customer_Age                                 0.016325         0.023097
# Gender_M                                     0.020816         0.474351
# Gender_F                                    -0.020816        -0.474351
# Dependent_count                             -0.003832         0.081674
# Education_Level_High School                  0.028286        -0.011331
# Education_Level_Graduate                    -0.011963        -0.000541
# Education_Level_Uneducated                  -0.000682         0.014908
# Education_Level_College                     -0.011015         0.006507
# Education_Level_Post-Graduate                0.010682        -0.002930
# Education_Level_Doctorate                   -0.022511        -0.008920
# Marital_Status_Married                       0.049873        -0.058023
# Marital_Status_Single                       -0.051508         0.049238
# Marital_Status_Divorced                      0.001674         0.017433
# Income_Category_$60K - $80K                 -0.008867         0.103930
# Income_Category_Less than $40K              -0.026772        -0.417037
# Income_Category_$80K - $120K                 0.027242         0.367182
# Income_Category_$40K - $60K                  0.002692        -0.172904
# Income_Category_$120K +                      0.018336         0.357275
# Card_Category_Blue                          -0.016744        -0.494403
# Card_Category_Gold                           0.022699         0.227106
# Card_Category_Silver                         0.006248         0.425213
# Card_Category_Platinum                       0.009657         0.085594
# Months_on_book                               0.007884         0.019391
# Total_Relationship_Count                     0.014313        -0.076107
# Months_Inactive_12_mon                      -0.039889        -0.012170
# Contacts_Count_12_mon                       -0.048690         0.021059
# Credit_Limit                                 0.038170         0.996041
# Total_Revolving_Bal                          1.000000        -0.050812
# Avg_Open_To_Buy                             -0.050812         1.000000
# Total_Amt_Chng_Q4_Q1                         0.061685        -0.003516
# Total_Trans_Amt                              0.063782         0.165821
# Total_Trans_Ct                               0.052091         0.076154
# Total_Ct_Chng_Q4_Q1                          0.083746        -0.013438
# Avg_Utilization_Ratio                        0.626391        -0.539100
#
#                                   Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# Attrition_Flag_Existing Customer              0.132702         0.160378
# Attrition_Flag_Attrited Customer             -0.132702        -0.160378
# Customer_Age                                 -0.068976        -0.045859
# Gender_M                                      0.034839         0.034648
# Gender_F                                     -0.034839        -0.034648
# Dependent_count                              -0.033320         0.023236
# Education_Level_High School                   0.000154         0.003117
# Education_Level_Graduate                     -0.012657        -0.000157
# Education_Level_Uneducated                    0.008064         0.009537
# Education_Level_College                       0.012083        -0.013940
# Education_Level_Post-Graduate                 0.013288         0.009898
# Education_Level_Doctorate                    -0.018668        -0.012209
# Marital_Status_Married                        0.056678        -0.066627
# Marital_Status_Single                        -0.053513         0.057080
# Marital_Status_Divorced                      -0.007206         0.019037
# Income_Category_$60K - $80K                   0.027616         0.010404
# Income_Category_Less than $40K               -0.031922        -0.016547
# Income_Category_$80K - $120K                  0.023340         0.012059
# Income_Category_$40K - $60K                   0.005460        -0.005263
# Income_Category_$120K +                      -0.019662         0.006935
# Card_Category_Blue                            0.009111        -0.188797
# Card_Category_Gold                            0.002177         0.121926
# Card_Category_Silver                         -0.011395         0.140400
# Card_Category_Platinum                        0.001890         0.065082
# Months_on_book                               -0.059865        -0.037625
# Total_Relationship_Count                      0.053147        -0.348024
# Months_Inactive_12_mon                       -0.028157        -0.039977
# Contacts_Count_12_mon                        -0.027849        -0.121018
# Credit_Limit                                  0.001973         0.171591
# Total_Revolving_Bal                           0.061685         0.063782
# Avg_Open_To_Buy                              -0.003516         0.165821
# Total_Amt_Chng_Q4_Q1                          1.000000         0.027295
# Total_Trans_Amt                               0.027295         1.000000
# Total_Trans_Ct                               -0.004579         0.810073
# Total_Ct_Chng_Q4_Q1                           0.390099         0.084232
# Avg_Utilization_Ratio                         0.038991        -0.086053
#
#                                   Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# Attrition_Flag_Existing Customer        0.357261             0.280460
# Attrition_Flag_Attrited Customer       -0.357261            -0.280460
# Customer_Age                           -0.069883            -0.017599
# Gender_M                               -0.055468            -0.007336
# Gender_F                                0.055468             0.007336
# Dependent_count                         0.057056             0.019081
# Education_Level_High School             0.000898             0.000407
# Education_Level_Graduate               -0.004422             0.000382
# Education_Level_Uneducated              0.007516             0.015138
# Education_Level_College                -0.000600             0.008889
# Education_Level_Post-Graduate           0.001118            -0.017657
# Education_Level_Doctorate              -0.005230            -0.021459
# Marital_Status_Married                 -0.132957             0.003150
# Marital_Status_Single                   0.115800            -0.000695
# Marital_Status_Divorced                 0.034556            -0.004533
# Income_Category_$60K - $80K            -0.019664             0.025627
# Income_Category_Less than $40K          0.044240             0.002300
# Income_Category_$80K - $120K           -0.031965            -0.001218
# Income_Category_$40K - $60K             0.004503            -0.001788
# Income_Category_$120K +                -0.015736            -0.033929
# Card_Category_Blue                     -0.132160             0.004333
# Card_Category_Gold                      0.091830             0.000222
# Card_Category_Silver                    0.094512            -0.002524
# Card_Category_Platinum                  0.049924            -0.013696
# Months_on_book                         -0.050445            -0.028528
# Total_Relationship_Count               -0.246749             0.036900
# Months_Inactive_12_mon                 -0.048169            -0.039581
# Contacts_Count_12_mon                  -0.155612            -0.099544
# Credit_Limit                            0.080834            -0.005991
# Total_Revolving_Bal                     0.052091             0.083746
# Avg_Open_To_Buy                         0.076154            -0.013438
# Total_Amt_Chng_Q4_Q1                   -0.004579             0.390099
# Total_Trans_Amt                         0.810073             0.084232
# Total_Trans_Ct                          1.000000             0.107596
# Total_Ct_Chng_Q4_Q1                     0.107596             1.000000
# Avg_Utilization_Ratio                  -0.002141             0.072361
#
#                                   Avg_Utilization_Ratio
# Attrition_Flag_Existing Customer               0.183984
# Attrition_Flag_Attrited Customer              -0.183984
# Customer_Age                                   0.001296
# Gender_M                                      -0.309002
# Gender_F                                       0.309002
# Dependent_count                               -0.042485
# Education_Level_High School                    0.013911
# Education_Level_Graduate                      -0.002013
# Education_Level_Uneducated                    -0.004793
# Education_Level_College                       -0.009862
# Education_Level_Post-Graduate                  0.009681
# Education_Level_Doctorate                     -0.010195
# Marital_Status_Married                         0.045873
# Marital_Status_Single                         -0.040669
# Marital_Status_Divorced                       -0.010625
# Income_Category_$60K - $80K                   -0.120166
# Income_Category_Less than $40K                 0.272828
# Income_Category_$80K - $120K                  -0.196660
# Income_Category_$40K - $60K                    0.071465
# Income_Category_$120K +                       -0.163230
# Card_Category_Blue                             0.217179
# Card_Category_Gold                            -0.086608
# Card_Category_Silver                          -0.193669
# Card_Category_Platinum                        -0.033200
# Months_on_book                                -0.010007
# Total_Relationship_Count                       0.069073
# Months_Inactive_12_mon                        -0.003179
# Contacts_Count_12_mon                         -0.043495
# Credit_Limit                                  -0.483649
# Total_Revolving_Bal                            0.626391
# Avg_Open_To_Buy                               -0.539100
# Total_Amt_Chng_Q4_Q1                           0.038991
# Total_Trans_Amt                               -0.086053
# Total_Trans_Ct                                -0.002141
# Total_Ct_Chng_Q4_Q1                            0.072361
# Avg_Utilization_Ratio                          1.000000
#
# [36 rows x 36 columns]

# %%
#heatmap으로 상관관계를 표시
import seaborn as sb
plt.rcParams["figure.figsize"] = (20,20)
sb.heatmap(df_encoded.corr(),
           annot = True, #실제 값 화면에 나타내기
           cmap = 'Greens', #색상
           vmin = -1, vmax=1 , #컬러차트 영역 -1 ~ +1
          )

# %%
# 이탈한 고객과 상관계수가 높은 컬럼 순으로 보기

df_encoded.corr()['Attrition_Flag_Attrited Customer'].sort_values(ascending=False)
# Out:
# Attrition_Flag_Attrited Customer    1.000000
# Contacts_Count_12_mon               0.193923
# Months_Inactive_12_mon              0.152732
# Gender_F                            0.035358
# Education_Level_Doctorate           0.033169
# Income_Category_Less than $40K      0.027114
# Marital_Status_Single               0.022535
# Income_Category_$120K +             0.017218
# Education_Level_Post-Graduate       0.015019
# Card_Category_Platinum              0.012522
# Dependent_count                     0.011423
# Months_on_book                      0.009249
# Customer_Age                        0.008735
# Avg_Open_To_Buy                     0.007802
# Marital_Status_Divorced             0.003659
# Card_Category_Silver                0.002620
# Card_Category_Gold                  0.000979
# Income_Category_$80K - $120K        0.000070
# Education_Level_College            -0.000791
# Education_Level_Graduate           -0.001012
# Education_Level_Uneducated         -0.003353
# Card_Category_Blue                 -0.004743
# Credit_Limit                       -0.015815
# Income_Category_$40K - $60K        -0.017421
# Education_Level_High School        -0.020932
# Marital_Status_Married             -0.024207
# Income_Category_$60K - $80K        -0.030356
# Gender_M                           -0.035358
# Total_Amt_Chng_Q4_Q1               -0.132702
# Total_Relationship_Count           -0.145713
# Total_Trans_Amt                    -0.160378
# Avg_Utilization_Ratio              -0.183984
# Total_Revolving_Bal                -0.265380
# Total_Ct_Chng_Q4_Q1                -0.280460
# Total_Trans_Ct                     -0.357261
# Attrition_Flag_Existing Customer   -1.000000
# Name: Attrition_Flag_Attrited Customer, dtype: float64

# %%
boolearn_attrited_customer = df['Attrition_Flag'] == 'Attrited Customer'
new_df = df[boolearn_attrited_customer]

# %%
new_df
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21     Attrited Customer            62      F                0
# 51     Attrited Customer            54      F                1
# 54     Attrited Customer            56      M                2
# 61     Attrited Customer            48      M                2
# 127    Attrited Customer            53      M                2
# ...                  ...           ...    ...              ...
# 10108  Attrited Customer            47      M                4
# 10112  Attrited Customer            33      M                2
# 10113  Attrited Customer            27      M                0
# 10124  Attrited Customer            44      F                1
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 21           Graduate        Married  Less than $40K          Blue
# 51           Graduate        Married  Less than $40K          Blue
# 54           Graduate        Married         $120K +          Blue
# 61           Graduate        Married     $60K - $80K        Silver
# 127          Graduate        Married    $80K - $120K          Blue
# ...               ...            ...             ...           ...
# 10108        Graduate       Divorced    $80K - $120K          Blue
# 10112         College        Married         $120K +          Gold
# 10113     High School       Divorced     $60K - $80K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 21                 49                         2                       3
# 51                 40                         2                       3
# 54                 36                         1                       3
# 61                 35                         2                       4
# 127                41                         3                       3
# ...               ...                       ...                     ...
# 10108              39                         4                       3
# 10112              20                         2                       1
# 10113              36                         2                       3
# 10124              36                         5                       3
# 10126              25                         6                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 21                         3        1438.3                    0
# 51                         1        1438.3                  808
# 54                         3       15769.0                    0
# 61                         4       34516.0                    0
# 127                        2       11669.0                 2227
# ...                      ...           ...                  ...
# 10108                      4       17504.0                  476
# 10112                      4       34516.0                    0
# 10113                      2       13303.0                 2517
# 10124                      4        5409.0                    0
# 10126                      4       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 21              1438.3                 1.047              692              16
# 51               630.3                 0.997              705              19
# 54             15769.0                 1.041              602              15
# 61             34516.0                 0.763              691              15
# 127             9442.0                 0.622              720              23
# ...                ...                   ...              ...             ...
# 10108          17028.0                 0.892            10468              66
# 10112          34516.0                 1.004             9338              73
# 10113          10786.0                 0.929            10219              85
# 10124           5409.0                 0.819            10291              60
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 21                   0.600                  0.000
# 51                   0.900                  0.562
# 54                   0.364                  0.000
# 61                   0.500                  0.000
# 127                  0.353                  0.191
# ...                    ...                    ...
# 10108                0.737                  0.027
# 10112                0.622                  0.000
# 10113                0.809                  0.189
# 10124                0.818                  0.000
# 10126                0.649                  0.189
#
# [1113 rows x 20 columns]

# %%
# Attrited Customer인 인덱스만 추출하여 시각화

# %%
# %matplotlib inline
df_marital = new_df['Marital_Status']
sns.countplot(x= df_marital);
df['Marital_Status'].value_counts(normalize=True)
# Out:
# Married     0.503319
# Single      0.416325
# Divorced    0.080356
# Name: Marital_Status, dtype: float64

# %%
# %matplotlib inline
df_Education_Level = new_df['Education_Level']
sns.countplot(x= df_Education_Level);
df['Education_Level'].value_counts(normalize=True)
# Out:
# Graduate         0.365909
# High School      0.233442
# Uneducated       0.170032
# College          0.119192
# Post-Graduate    0.060867
# Doctorate        0.050558
# Name: Education_Level, dtype: float64

# %%
# %matplotlib inline
df_Income_Category = new_df['Income_Category']
sns.countplot(x= df_Income_Category);
df['Income_Category'].value_counts(normalize=True)
# Out:
# Less than $40K    0.394295
# $40K - $60K       0.199407
# $80K - $120K      0.169750
# $60K - $80K       0.155769
# $120K +           0.080780
# Name: Income_Category, dtype: float64

# %%
# %matplotlib inline
df_Contacts_Count_12_mon = new_df['Contacts_Count_12_mon']
sns.countplot(x= df_Contacts_Count_12_mon);
df['Contacts_Count_12_mon'].value_counts(normalize=True)
# Out:
# 3    0.332439
# 2    0.320717
# 1    0.145318
# 4    0.138116
# 0    0.040672
# 5    0.018500
# 6    0.004237
# Name: Contacts_Count_12_mon, dtype: float64

# %%
# %matplotlib inline
df_Months_Inactive_12_mon = new_df['Months_Inactive_12_mon']
sns.countplot(x= df_Months_Inactive_12_mon);
df['Months_Inactive_12_mon'].value_counts(normalize=True)
# Out:
# 3    0.384691
# 2    0.327637
# 1    0.215365
# 4    0.040813
# 5    0.018218
# 6    0.010592
# 0    0.002683
# Name: Months_Inactive_12_mon, dtype: float64

# %% [markdown]
# # 로지스틱리그레션 모델 만들기

# %%
# 로지스틱리그레션 모델 만들기
# 타겟이 'Existing Customer'과 'Attrited Customer'로 나뉘는 분류문제이므로 0과 1사이의 값으로 결과를 내는 로지스틱 회귀(Logistic Regression)를 사용 )


model = LogisticRegression(random_state=1)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
y_pred = model.predict(X_val_scaled)
accuracy_score(y_val, y_pred)
# Out:
# 0.904380012338063

# %%
coefficients = pd.Series(model.coef_[0], X_train_encoded.columns)
coefficients.sort_values(ascending=True)
# Out:
# Total_Trans_Amt                  -1.546824
# Contacts_Count_12_mon            -0.529321
# Months_Inactive_12_mon           -0.508594
# Gender_F                         -0.229781
# Dependent_count                  -0.177283
# Income_Category_$120K +          -0.171775
# Marital_Status_Single            -0.138782
# Card_Category_Gold               -0.111789
# Income_Category_$80K - $120K     -0.101278
# Education_Level_Doctorate        -0.098613
# Marital_Status_Unknown           -0.059339
# Card_Category_Silver             -0.053082
# Card_Category_Platinum           -0.052117
# Income_Category_$60K - $80K      -0.036114
# Education_Level_Post-Graduate    -0.030856
# Marital_Status_Divorced          -0.017196
# Education_Level_Uneducated       -0.012132
# Months_on_book                   -0.007089
# Education_Level_Unknown           0.003246
# Education_Level_High School       0.017255
# Education_Level_Graduate          0.030709
# Education_Level_College           0.031391
# Income_Category_Less than $40K    0.045069
# Income_Category_Unknown           0.066451
# Avg_Utilization_Ratio             0.085732
# Customer_Age                      0.090357
# Card_Category_Blue                0.105139
# Avg_Open_To_Buy                   0.105463
# Income_Category_$40K - $60K       0.131020
# Total_Amt_Chng_Q4_Q1              0.150479
# Credit_Limit                      0.170629
# Marital_Status_Married            0.176393
# Gender_M                          0.229781
# Total_Ct_Chng_Q4_Q1               0.631493
# Total_Revolving_Bal               0.722209
# Total_Relationship_Count          0.759755
# Total_Trans_Ct                    2.734147
# dtype: float64

# %%
coefficients.sort_values().plot.barh().ascending=True;

# %% [markdown]
# # 하이퍼파라미터 작업

# %% [markdown]
# ## - GridSearch로 최적의 하이퍼파라미터 값 찾기

# %%
hyper_parameter = {
    'alpha' : [0.01, 0.1, 1, 10],
    'max_iter' : [100, 500, 1000, 1500, 2000]
}

# %%
lasso_model = Lasso()

# %%
from sklearn.model_selection import GridSearchCV

hyper_parameter_tuner = GridSearchCV(lasso_model, hyper_parameter, cv=5)
hyper_parameter_tuner.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05571082982038433, tolerance: 0.04864942052980128
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06328036902266376, tolerance: 0.049194648275862146
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.055709054114174705, tolerance: 0.04864942052980128
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06327859672825298, tolerance: 0.049194648275862146
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05570683447564306, tolerance: 0.04864942052980128
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06327638134598601, tolerance: 0.049194648275862146
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05570461484302314, tolerance: 0.04864942052980128
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06327416597184765, tolerance: 0.049194648275862146
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.055702395199148214, tolerance: 0.04864942052980128
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0632719505911723, tolerance: 0.049194648275862146
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10],
#                          'max_iter': [100, 500, 1000, 1500, 2000]})

# %%
#최적의 파라미터값

hyper_parameter_tuner.best_params_
# Out:
# {'alpha': 0.01, 'max_iter': 100}

# %% [markdown]
# ## RandomizedSearchCV로 최적의 파라미터값 찾기

# %%
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='xgboost')

from scipy.stats import randint, uniform

param_distributions = { 
    'n_estimators': randint(50, 500), 
    'max_depth': [5, 10, 15, 20, None], 
    'max_features': uniform(0, 1), 
}

search = RandomizedSearchCV(
    RandomForestClassifier(random_state=2), 
    param_distributions=param_distributions, 
    n_iter=5, 
    cv=3, 
    scoring='neg_mean_absolute_error', 
    verbose=10, 
    return_train_score=True, 
    n_jobs=-1, 
    random_state=2
)

search.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits

# %%
#최적의 파라미터값

print('최적 하이퍼파라미터: ', search.best_params_)
print('CV MAE: ', -search.best_score_)
model = search.best_estimator_
# Out:
# 최적 하이퍼파라미터:  {'max_depth': 20, 'max_features': 0.498561170053319, 'n_estimators': 476}
# CV MAE:  0.04237577850728214

# %% [markdown]
# # 파이프라인 만들어서 모델 학습

# %% [markdown]
# <분류 문제 평가 지표>
#
# 정밀도 : 양성으로 예측된 것(TP+FP) 중 얼마나 많은 샘플이 진짜 양성(TP)인지 측정
# 거짓 양성의 수를 줄이는 것이 목표일 때 사용(ex. 비싼 신약의 효과를 단 한 번의 실험으로 검증하기를 원할 때)
#
# 재현율 : 전체 양성 샘플 중 얼마나 많은 샘플이 양성 클래스로 분류되는지 측정. 거짓 음성을 피하는 것이 중요할 때, 즉 모든 양성 샘플을 식별해야 할 때 사용
# (ex. 건강한 사람이 일부 포함되더라도 암에 걸린 사람을 빠짐없이 찾는 것이 중요)
#
# F1_score : 정밀도와 재현율의 조화 평균

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report


# pipe1 : 결정트리
# 복잡한 트리는 과적합 가능성을 높이기 때문에 복잡도를 낮추어 일반화를 유도합니다
# 트리의 복잡도를 줄이기 위해 사용하는 하이퍼파라미터들
# min_samples_split
# min_samples_leaf
# max_depth


pipe1 = make_pipeline(
    DecisionTreeClassifier(max_depth=6, min_samples_leaf=10, random_state=2) 
)


# 파이프라인 학습
pipe1.fit(X_train_scaled, y_train)

pred_pipe1 = pipe1.predict(X_val_scaled)


print('pipe1 훈련 정확도 점수:', pipe1.score(X_train_scaled, y_train))
print('pipe1 검증 정확도 점수:', pipe1.score(X_val_scaled, y_val))
print('\n')


print('pipe1 정확도 점수: ', accuracy_score(y_val, pred_pipe1))
print('\n')

confusion_pipe1 = confusion_matrix(y_val, pred_pipe1)
print("오차행렬:\n", confusion_pipe1)
print('\n')

print("~ pipe1 학습 결과 평가 지표 ~\n\n")
print(classification_report(y_val, pred_pipe1))
# Out:
# pipe1 훈련 정확도 점수: 0.9550925925925926
# pipe1 검증 정확도 점수: 0.9413942011104257
#
#
# pipe1 정확도 점수:  0.9413942011104257
#
#
# 오차행렬:
#  [[ 204   61]
#  [  34 1322]]
#
#
# ~ pipe1 학습 결과 평가 지표 ~
#
#
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.86      0.77      0.81       265
# Existing Customer       0.96      0.97      0.97      1356
#
#          accuracy                           0.94      1621
#         macro avg       0.91      0.87      0.89      1621
#      weighted avg       0.94      0.94      0.94      1621

# %% [markdown]
# ##### 분류기의 정확한 성능을 판단하기 위해서는 정확도 외에 다른 평가지표를 같이 사용해야 합니다.
# ##### 특히 정밀도(precision), 재현율(recall) 을 살펴보아야 합니다.
#
#
# 정확도(Accuracy)는 전체 범주를 모두 바르게 맞춘 경우를 전체 수로 나눈 값입니다: $\large \frac{TP + TN}{Total}$
#
# 정밀도(Precision)는 Positive로 예측한 경우 중 올바르게 Positive를 맞춘 비율입니다: $\large \frac{TP}{TP + FP}$
#
# 재현율(Recall, Sensitivity)은 실제 Positive인 것 중 올바르게 Positive를 맞춘 것의 비율 입니다: $\large \frac{TP}{TP + FN}$
#
# F1점수(F1 score)는 정밀도와 재현율의 조화평균(harmonic mean)입니다: $ 2\cdot\large\frac{precision\cdot recall}{precision + recall}$

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
pcm = plot_confusion_matrix(pipe1, X_val_scaled, y_val,
                            cmap=plt.cm.Blues,
                            ax=ax);
plt.title(f'Confusion matrix, n = {len(y_val)}', fontsize=15)
plt.show()

# %%
# pipe2 : 로지스틱회귀

pipe2 = make_pipeline(
    StandardScaler(),
    LogisticRegression(random_state=1)#(solver='saga', max_iter=2000)
)


# 파이프라인 학습
pipe2.fit(X_train_scaled, y_train)

pred_pipe2 = pipe2.predict(X_val_scaled)



print('pipe2 훈련 정확도 점수:', pipe2.score(X_train_scaled, y_train))
print('pipe2 검증 정확도 점수:', pipe2.score(X_val_scaled, y_val))
print('\n')



print('pipe2 정확도 점수: ', accuracy_score(y_val, pred_pipe2))
print('\n')

confusion_pipe1 = confusion_matrix(y_val, pred_pipe2)
print("오차행렬:\n", confusion_pipe1)
print('\n')

print("~ pipe2 학습 결과 평가 지표 ~\n\n")
print(classification_report(y_val, pred_pipe2))
# Out:
# pipe2 훈련 정확도 점수: 0.9061728395061729
# pipe2 검증 정확도 점수: 0.904380012338063
#
#
# pipe2 정확도 점수:  0.904380012338063
#
#
# 오차행렬:
#  [[ 151  114]
#  [  41 1315]]
#
#
# ~ pipe2 학습 결과 평가 지표 ~
#
#
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.79      0.57      0.66       265
# Existing Customer       0.92      0.97      0.94      1356
#
#          accuracy                           0.90      1621
#         macro avg       0.85      0.77      0.80      1621
#      weighted avg       0.90      0.90      0.90      1621

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
pcm = plot_confusion_matrix(pipe2, X_val_scaled, y_val,
                            cmap=plt.cm.Blues,
                            ax=ax);
plt.title(f'Confusion matrix, n = {len(y_val)}', fontsize=15)
plt.show()

# %%
# pipe3 : 랜덤포레스트

pipe3 = make_pipeline(
#     OrdinalEncoder(),
    OneHotEncoder(use_cat_names=True),
    SimpleImputer(), 
    RandomForestClassifier(random_state=10, n_jobs=-1, oob_score=True)
)




# 파이프라인 학습
pipe3.fit(X_train_scaled, y_train)

pred_pipe3 = pipe3.predict(X_val_scaled)




print('pipe3 훈련 정확도 점수:', pipe3.score(X_train_scaled, y_train))
print('pipe3 검증 정확도 점수:', pipe3.score(X_val_scaled, y_val))
print('\n')
print('pipe3 정확도 점수: ', accuracy_score(y_val, pred_pipe3))


print('\n')

confusion_pipe3 = confusion_matrix(y_val, pred_pipe3)
print("오차행렬:\n", confusion_pipe3)
print('\n')

print("~ pipe3 학습 결과 평가 지표 ~\n\n")
print(classification_report(y_val, pred_pipe3))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# pipe3 훈련 정확도 점수: 1.0
# pipe3 검증 정확도 점수: 0.958667489204195
#
#
# pipe3 정확도 점수:  0.958667489204195
#
#
# 오차행렬:
#  [[ 211   54]
#  [  13 1343]]
#
#
# ~ pipe3 학습 결과 평가 지표 ~
#
#
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.94      0.80      0.86       265
# Existing Customer       0.96      0.99      0.98      1356
#
#          accuracy                           0.96      1621
#         macro avg       0.95      0.89      0.92      1621
#      weighted avg       0.96      0.96      0.96      1621

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
pcm = plot_confusion_matrix(pipe3, X_val_scaled, y_val,
                            cmap=plt.cm.Blues,
                            ax=ax);
plt.title(f'Confusion matrix, n = {len(y_val)}', fontsize=15)
plt.show()

# %%
# pipe4 : 결정트리(pipe1)모델의 파라미터값 조절해보기

pipe4 = make_pipeline(
    DecisionTreeClassifier(max_depth=6, min_samples_leaf=3, random_state=2) # min_samples_leaf=5 경우 훈련, 검증정확도는 좋지만 MAE값은 더 커짐. 
)

# 파이프라인 학습
pipe4.fit(X_train_scaled, y_train)

pred_pipe4 = pipe4.predict(X_val_scaled)



print('pipe4 훈련 정확도 점수:', pipe4.score(X_train_scaled, y_train))
print('pipe4 검증 정확도 점수:', pipe4.score(X_val_scaled, y_val))
print('\n')



print('pipe4 정확도 점수: ', accuracy_score(y_val, pred_pipe4))
print('\n')

confusion_pipe4 = confusion_matrix(y_val, pred_pipe4)
print("오차행렬:\n", confusion_pipe4)
print('\n')

print("~ pipe4 학습 결과 평가 지표 ~\n\n")
print(classification_report(y_val, pred_pipe4))
# Out:
# pipe4 훈련 정확도 점수: 0.9604938271604938
# pipe4 검증 정확도 점수: 0.9475632325724861
#
#
# pipe4 정확도 점수:  0.9475632325724861
#
#
# 오차행렬:
#  [[ 210   55]
#  [  30 1326]]
#
#
# ~ pipe4 학습 결과 평가 지표 ~
#
#
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.88      0.79      0.83       265
# Existing Customer       0.96      0.98      0.97      1356
#
#          accuracy                           0.95      1621
#         macro avg       0.92      0.89      0.90      1621
#      weighted avg       0.95      0.95      0.95      1621

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
pcm = plot_confusion_matrix(pipe4, X_val_scaled, y_val,
                            cmap=plt.cm.Blues,
                            ax=ax);
plt.title(f'Confusion matrix, n = {len(y_val)}', fontsize=15)
plt.show()

# %% [markdown]
# # 테스트 데이터 세트로 모델 성능 확인해보기

# %%
# 최종모델은 랜덤포레스트를 이용한 머신러닝 모델 사용




# 파이프라인 학습
pipe1.fit(X_test_scaled, y_test)

pred_test = pipe1.predict(X_test_scaled)

print('<최종 모델 테스트 평가>\n')

print('final 정확도 점수: ', accuracy_score(y_test, pred_test))
print('\n')

confusion_final = confusion_matrix(y_test, pred_test)
print("오차행렬:\n", confusion_final)
print('\n')

print("~ final 학습 결과 평가 지표 ~\n\n")
print(classification_report(y_test, pred_test))
# Out:
# <최종 모델 테스트 평가>
#
# final 정확도 점수:  0.93928923988154
#
#
# 오차행렬:
#  [[ 276   36]
#  [  87 1627]]
#
#
# ~ final 학습 결과 평가 지표 ~
#
#
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.76      0.88      0.82       312
# Existing Customer       0.98      0.95      0.96      1714
#
#          accuracy                           0.94      2026
#         macro avg       0.87      0.92      0.89      2026
#      weighted avg       0.94      0.94      0.94      2026

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
pcm = plot_confusion_matrix(pipe1, X_test_scaled, y_test,
                            cmap=plt.cm.Blues,
                            ax=ax);
plt.title(f'Confusion matrix, n = {len(y_test)}', fontsize=15)
plt.show()
